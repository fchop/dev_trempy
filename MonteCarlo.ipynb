# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from trempy.tests.test_auxiliary import visualize_modelfit

# %%
df_truth = pd.read_pickle(r'estimate_most_favorable/truth.trempy.pkl')
df_estimated = pd.read_pickle(r'estimate_most_favorable/stop/stop.trempy.pkl')

# %%
visualize_modelfit(df_truth, df_estimated)
# Out:
# Dropped question: 4
# Interior: 0.0
# Dropped question: 5
# Interior: 0.0
# Dropped question: 6
# Interior: 0.0
# Dropped question: 9
# Interior: 0.0
# Dropped question: 10
# Interior: 0.0
# Dropped question: 15
# Interior: 0.0
# Dropped question: 16
# Interior: 0.0
# Dropped question: 18
# Interior: 0.0
# Dropped question: 19
# Interior: 0.0
# Dropped question: 22
# Interior: 0.0
# Dropped question: 23
# Interior: 0.0
# Dropped question: 24
# Interior: 0.0
# Dropped question: 26
# Interior: 0.0005
# Dropped question: 28
# Interior: 0.0015
# Dropped question: 30
# Interior: 0.0
# Dropped question: 36
# Interior: 0.0685
